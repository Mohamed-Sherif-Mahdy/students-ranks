# %%
from selenium import webdriver
list=['20191320561',
'20191566041',
'20191480594',
'20191480244',
'20191613685',
'20191613511',
'20191615301',
'20191480280',
'20191041238',
'20191480196',
'20191616132',
'20191480309',
'20191567108',
'20191320913',
'20191613527',
'20191614312',
'20191478614',
'20201370151',
'20201497546',
'20201470460',
'20201321611',
'20201383007',
'20201475688',
'20201032790',
'20201476795',
'20201491232',
'20201497503',
'20201377243',
'20201496372',
'20201498487',
'20201444830',
'20201010800',
'20201376949',
'20201445797',
'20201374279',
'20201473970',
'20201010784',
'20201374583',
'20201498494',
'20201376153',
'20201495483',
'20201444610',
'20201375097',
'20201445388',
'20201498907',
'20201371627',
'20201499272',
'20201496337',
'20201447313',
'20201499917',
'20201378352',
'20201499038',
'20201373788',
'20201490939',
'20201445329',
'20201496451',
'20201379022',
'20201498994',
'20201381735',
'20201448026',
'20201475860',
'20201446771',
'20201498403',
'20201381068',
'20201471311',
'20201496805',
'20201499286',
'20201497622',
'20201474363',
'20201446454',
'20201378991',
'20201445843',
'20201498629',
'20201380516',
'20201444709',
'20201475307',
'20201496700',
'20201381362',
'20201445344',
'20201371093',
'20201080181',
'20201503334',
'20201210053',
'20201376238',
'20201497292',
'20201376874',
'20201379453',
'20201381037',
'20201423170',
'20201378673',
'20201498752',
'20201498519',
'20201379592',
'20201496815',
'20201472663',
'20201496463',
'20201497647',
'20201499396',
'20201495517',
'20201422800',
'20201374050',
'20201376979',
'20201477993',
'20201495525',
'20201470085',
'20201444840',
'20201447533',
'20201446699',
'20201497684',
'20201040753',
'20201040861',
'20201376239',
'20201377401',
'20201498682',
'20201382330',
'20201498637',
'20201382331',
'20201496620',
'20201374157',
'20201445800',
'20201374002',
'20201290382',
'20201375851',
'20201474201',
'20201497739',
'20201470332',
'20201447840',
'20201374538',
'20201446854',
'20201498197',
'20201442444',
'20201474079',
'20201474080',
'20201496820',
'20201381050',
'20201474089',
'20201476313',
'20201373615',
'20201375146',
'20201472028',
'20201378044',
'20201497770',
'20201497772',
'20201447462',
'20201498645',
'20201374289',
'20201372615',
'20201496716',
'20201377368',
'20201310817',
'20201447866',
'20201494864',
'20201368842',
'20201444880',
'20201497461',
'20201376816',
'20201498657',
'20201494866',
'20201495669',
'20201210256',
'20201375952',
'20201370943',
'20201470176',
'20201474689',
'20201474143',
'20201496722',
'20201374603',
'20201498249',
'20201446971',
'20201375186',
'20201444727',
'20201499017',
'20201472040',
'20201498255',
'20201447827',
'20201376938',
'20201498262',
'20201499409',
'20201378920',
'20201381265',
'20201374343',
'20201373760',
'20201499416',
'20201378363',
'20201380971',
'20201378683',
'20201496986',
'20201382972',
'20201423274',
'20201448030',
'20201507601',
'20201382436',
'20201378544',
'20201378204',
'20201447071',
'20201378053',
'20201498820',
'20201423108',
'20201378019',
'20201447189',
'20201491055',
'20201446416',
'20201381733',
'20201498579',
'20201030112',
'20201378393',
'20201470222',
'20201373703',
'20201373704',
'20201010819',
'20201500046',
'20201498707',
'20201446532',
'20201446811',
'20201011201',
'20201389393',
'20201388063',
'20201447426',
'20201291068',
'20201210582',
'20201010836',
'20201210672',
'20201010806',
'20201011198',
'20201041918',
'20201010856',
'20201080552',
'20201372121',
'20201311194',
'20201060198',
'20201150039',
'20201290557',
'20201150407',
'20201040896',
'20201060677',
'20201311889',
'20201060070',
'20201010791',
'20201031276',
'20201010817',
'20201323258',
'20201290250',
'20201290050',
'20201447464',
'20201495703',
'20201370938',
'20201378219',
'20201378214',
'20201371755',
'20201371437',
'20201370879',
'20201447422',
'20201322822',
'20201372720',
'20201373309',
'20201446543',
'20201446680',
'20201370857',
'20201447980',
'20201495700',
'20201447397',
'20201655977',
'20201907608',
'20201494813',
'20201370970',
'20201498695',
'20201498528',
'20201164698',
'20201496214',
'20201110001',
'20201312674',
'20201937936',
'20201038488',
'20201312604',
'20201312670',
'20201472484',
'20201495709'
]
for i in list:
    path= "C:\\Drivers\\chromedriver.exe"
    driver = webdriver.Chrome(path)
    driver.get("http://sci.p.alexu.edu.eg/ayounes/_FCDS_ExResults/?fbclid=IwAR0QqPkeXCRZ2VWs9OZCMTXbdERFzHWOcLgBTr89xxL3vBEtHIQoXETLpI8")
    search_box=driver.find_element_by_xpath("/html/body/form/div[5]/div[1]/input[1]")
    search_box.send_keys(i)
    enter=driver.find_element_by_xpath("/html/body/form/div[5]/div[1]/input[2]")
    enter.click()
    data=driver.find_element_by_xpath("/html/body/form/div[5]/div[1]/span[4]")
    print(data.text)
    driver.close()
# Out:
# GPA: 0.88
# GPA: 1.96
# GPA: 2.53
# GPA: 2.16
# GPA: 1.27
# GPA: 2.00
# GPA: 1.31
# GPA: 1.02
# GPA: 0.00
# GPA: 2.50
# GPA: 1.33
# GPA: 0.75
# GPA: 0.50
# GPA: 2.56
# GPA: 0.00
# GPA: 2.94
# GPA: 2.07
# GPA: 3.27
# GPA: 3.87
# GPA: 0.00
# GPA: 3.40
# GPA: 3.54
# GPA: 2.13
# GPA: 3.73
# GPA: 0.00
# GPA: 3.80
# GPA: 2.93
# GPA: 0.00
# GPA: 1.53
# GPA: 3.07
# GPA: 1.93
# GPA: 3.13
# GPA: 1.13
# GPA: 0.00
# GPA: 0.00
# GPA: 2.13
# GPA: 3.53
# GPA: 3.07
# GPA: 2.80
# GPA: 2.07
# GPA: 2.20
# GPA: 3.20
# GPA: 3.53
# GPA: 0.00
# GPA: 1.87
# GPA: 3.60
# GPA: 3.33
# GPA: 3.73
# GPA: 2.53
# GPA: 3.87
# GPA: 3.80
# GPA: 3.13
# GPA: 2.14
# GPA: 0.00
# GPA: 0.00
# GPA: 2.73
# GPA: 3.27
# GPA: 3.33
# GPA: 3.13
# GPA: 3.87
# GPA: 1.00
# GPA: 3.60
# GPA: 3.73
# GPA: 2.53
# GPA: 1.47
# GPA: 2.93
# GPA: 3.27
# GPA: 1.80
# GPA: 0.00
# GPA: 3.80
# GPA: 3.67
# GPA: 2.47
# GPA: 3.00
# GPA: 2.87
# GPA: 3.33
# GPA: 1.80
# GPA: 3.67
# GPA: 3.20
# GPA: 0.00
# GPA: 3.06
# GPA: 0.00
# GPA: 2.00
# GPA: 1.07
# ...

# %%
GPA: 0.88
GPA: 1.96
GPA: 2.53
GPA: 2.16
GPA: 1.27
GPA: 2.00
GPA: 1.31
GPA: 1.02
GPA: 0.00
GPA: 2.50
GPA: 1.33
GPA: 0.75
GPA: 0.50
GPA: 2.56
GPA: 0.00
GPA: 2.94
GPA: 2.07
GPA: 3.27
GPA: 3.87
GPA: 0.00
GPA: 3.40
GPA: 3.54
GPA: 2.13
GPA: 3.73
GPA: 0.00
GPA: 3.80
GPA: 2.93
GPA: 0.00
GPA: 1.53
GPA: 3.07
GPA: 1.93
GPA: 3.13
GPA: 1.13
GPA: 0.00
GPA: 0.00
GPA: 2.13
GPA: 3.53
GPA: 3.07
GPA: 2.80
GPA: 2.07
GPA: 2.20
GPA: 3.20
GPA: 3.53
GPA: 0.00
GPA: 1.87
GPA: 3.60
GPA: 3.33
GPA: 3.73
GPA: 2.53
GPA: 3.87
GPA: 3.80
GPA: 3.13
GPA: 2.14
GPA: 0.00
GPA: 0.00
GPA: 2.73
GPA: 3.27
GPA: 3.33
GPA: 3.13
GPA: 3.87
GPA: 1.00
GPA: 3.60
GPA: 3.73
GPA: 2.53
GPA: 1.47
GPA: 2.93
GPA: 3.27
GPA: 1.80
GPA: 0.00
GPA: 3.80
GPA: 3.67
GPA: 2.47
GPA: 3.00
GPA: 2.87
GPA: 3.33
GPA: 1.80
GPA: 3.67
GPA: 3.20
GPA: 0.00
GPA: 3.06
GPA: 0.00
GPA: 2.00
GPA: 1.07
GPA: 3.80
GPA: 2.87
GPA: 3.33
GPA: 3.40
GPA: 3.40
GPA: 2.27
GPA: 3.93
GPA: 3.60
GPA: 3.20
GPA: 2.86
GPA: 3.33
GPA: 1.93
GPA: 2.00
GPA: 2.27
GPA: 1.27
GPA: 3.80
GPA: 3.33
GPA: 4.00
GPA: 1.27
GPA: 1.80
GPA: 3.67
GPA: 2.47
GPA: 3.53
GPA: 2.40
GPA: 3.47
GPA: 2.13
GPA: 1.13
GPA: 0.00
GPA: 1.93
GPA: 3.33
GPA: 2.67
GPA: 2.13
GPA: 1.67
GPA: 2.40
GPA: 3.40
GPA: 3.13
GPA: 3.27
GPA: 3.74
GPA: 3.40
GPA: 3.00
GPA: 3.67
GPA: 3.07
GPA: 2.07
GPA: 3.60
GPA: 3.00
GPA: 3.00
GPA: 3.47
GPA: 2.73
GPA: 2.67
GPA: 1.67
GPA: 2.93
GPA: 2.87
GPA: 3.00
GPA: 3.20
GPA: 2.07
GPA: 3.87
GPA: 0.40
GPA: 3.73
GPA: 3.47
GPA: 1.20
GPA: 3.87
GPA: 1.40
GPA: 0.00
GPA: 1.13
GPA: 3.60
GPA: 3.27
GPA: 2.20
GPA: 3.80
GPA: 2.00
GPA: 2.73
GPA: 0.00
GPA: 2.27
GPA: 1.33
GPA: 3.53
GPA: 1.87
GPA: 3.40
GPA: 3.74
GPA: 2.26
GPA: 0.20
GPA: 2.60
GPA: 2.20
GPA: 2.00
GPA: 0.00
GPA: 3.80
GPA: 2.93
GPA: 3.73
GPA: 2.60
GPA: 3.07
GPA: 3.60
GPA: 0.00
GPA: 2.67
GPA: 4.00
GPA: 3.60
GPA: 1.80
GPA: 3.27
GPA: 3.80
GPA: 2.40
GPA: 3.60
GPA: 3.93
GPA: 3.73
GPA: 3.53
GPA: 2.73
GPA: 3.20
GPA: 3.20
GPA: 3.60
GPA: 3.40
GPA: 3.93
GPA: 0.00
GPA: 3.53
GPA: 3.33
GPA: 3.54
GPA: 3.33
GPA: 3.67
GPA: 3.20
GPA: 3.47
GPA: 0.00
GPA: 3.73
GPA: 3.33
GPA: 3.60
GPA: 3.40
GPA: 3.27
GPA: 2.53
GPA: 3.27
GPA: 3.87
GPA: 3.53
GPA: 2.93
GPA: 2.33
GPA: 1.93
GPA: 3.07
GPA: 3.60
GPA: 2.33
GPA: 0.00
GPA: 0.20
GPA: 0.00
GPA: 0.80
GPA: 0.00
GPA: 1.87
GPA: 2.87
GPA: 0.00
GPA: 0.00
GPA: 2.73
GPA: 0.00
GPA: 1.27
GPA: 1.73
GPA: 3.80
GPA: 0.00
GPA: 3.13
GPA: 2.54
GPA: 0.00
GPA: 1.13
GPA: 1.00
GPA: 3.93
GPA: 0.00
GPA: 3.00
GPA: 1.80
GPA: 1.53
GPA: 3.67
GPA: 1.40
GPA: 2.93
GPA: 0.00
GPA: 2.33
GPA: 2.60
GPA: 3.13
GPA: 2.40
GPA: 2.60
GPA: 2.87
GPA: 2.07
GPA: 2.80
GPA: 3.27
GPA: 1.93
GPA: 1.47
GPA: 1.80
GPA: 1.67
GPA: 3.27
GPA: 2.73
GPA: 3.40
GPA: 1.27
GPA: 2.20
GPA: 0.00
GPA: 0.00
GPA: 1.20
GPA: 0.20
GPA: 2.27
GPA: 1.40
GPA: 1.00
GPA: 0.00
GPA: 0.33
GPA: 1.33
GPA: 0.00
GPA: 1.13
GPA: 0.87
GPA: 1.00
GPA: 0.60
GPA: 1.53

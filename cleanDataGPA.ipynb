# %%
import pandas as pd
df = pd.read_csv('GPA3semester2023.csv')
new = df.GPA.str.split(" ", n = 1, expand = True)
df.GPA=new[1]
df.to_csv('cleanGPAfirstsemester2023.csv',encoding='utf-8-sig')
df
# Out:
#                                          name    studentID   GPA
# 0            ابانوب سمير جبرائيل ميخائيل جرجس  20191480244  2.16
# 1            ابانوب سمير جبرائيل ميخائيل جرجس  20191311461  3.71
# 2            ابانوب سمير جبرائيل ميخائيل جرجس  20191480247  2.35
# 3            ابانوب سمير جبرائيل ميخائيل جرجس  20191615136  3.35
# 4            ابانوب سمير جبرائيل ميخائيل جرجس  20191615142  2.51
# 5            ابانوب سمير جبرائيل ميخائيل جرجس  20191612310  3.00
# 6            ابانوب سمير جبرائيل ميخائيل جرجس  20191615143  2.80
# 7            ابانوب سمير جبرائيل ميخائيل جرجس  20191479464  2.57
# 8            ابانوب سمير جبرائيل ميخائيل جرجس  20191616039  1.47
# 9            ابانوب سمير جبرائيل ميخائيل جرجس  20191614703  0.61
# 10           ابانوب سمير جبرائيل ميخائيل جرجس  20191565981  2.79
# 11           ابانوب سمير جبرائيل ميخائيل جرجس  20191616041  2.94
# 12           ابانوب سمير جبرائيل ميخائيل جرجس  20191480249  2.73
# ...
